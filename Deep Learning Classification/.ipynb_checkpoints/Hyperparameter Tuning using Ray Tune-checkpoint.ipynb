# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('personality_dataset.csv')

# %%
pd.get_dummies(df[['Stage_fear','Drained_after_socializing']],)
# Out:
#       Stage_fear_No  Stage_fear_Yes  Drained_after_socializing_No  \
# 0                 1               0                             1
# 1                 0               1                             0
# 2                 0               1                             0
# 3                 1               0                             1
# 4                 1               0                             1
# ...             ...             ...                           ...
# 2895              1               0                             1
# 2896              1               0                             1
# 2897              0               1                             0
# 2898              0               1                             0
# 2899              1               0                             1
#
#       Drained_after_socializing_Yes
# 0                                 0
# 1                                 1
# 2                                 1
# ...
